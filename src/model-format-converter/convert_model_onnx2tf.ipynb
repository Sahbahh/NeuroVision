# %%
import os
import onnx
from onnx_tf.backend import prepare

TRAINED_MODEL_NAME_ONNX = 'brain_tumor_segmentation_model_v1.onnx'
onnx_path = os.path.join('saved_models',TRAINED_MODEL_NAME_ONNX)

tfjs_dir = 'tfjs_model'
tfjs_path = os.path.join('saved_models', tfjs_dir)

# Load the ONNX model
onnx_model = onnx.load(onnx_path)

# Convert the ONNX model to TensorFlow format using onnx-tf
tf_rep = prepare(onnx_model)
tf_rep.export_graph(tfjs_path)

# onnx2tf.convert.from_onnx(onnx_path, tfjs_path)

# Convert ONNX model to TensorFlow.js format
# tf_rep = tf2onnx.convert.from_onnx(onnx_path)
# tf_rep.export_graph(tfjs_path)

# Convert ONNX model to TensorFlow.js format
# graph_def = tf2onnx.onnx_graph.load_model(onnx_path)
# tf_rep = tf2onnx.tf2onnx.export_graph(graph_def)
# tf_rep.save_model(tfjs_dir)
print(f"TensorFlow.js model saved to {tfjs_path}")
# Out:
# C:\Users\kobuk\anaconda3\Lib\site-packages\tensorflow_addons\utils\tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(
# WARNING:absl:`input.1` is not a valid tf.function parameter name. Sanitizing to `input_1`.
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[1], line 16
#      14 # Convert the ONNX model to TensorFlow format using onnx-tf
#      15 tf_rep = prepare(onnx_model)
# ---> 16 tf_rep.export_graph(tfjs_path)
# ...
